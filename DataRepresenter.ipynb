# %%
import numpy as np
import pandas as pd
import yaml
import json

# %%
df_meta_details = pd.read_csv('MatchDetails.csv')

# %%
list_of_cols = df_meta_details.columns.tolist()
list_of_cols = list_of_cols[1:]
df_meta_details = df_meta_details[list_of_cols]
df_meta_details
# Out:
#          file_name        Team_1                Team_2  \
# 0        file0.csv     Australia              Pakistan
# 1        file1.csv     Australia              Pakistan
# 2        file2.csv     Australia              Pakistan
# 3        file3.csv     Australia              Pakistan
# 4        file4.csv     Australia              Pakistan
# 5        file5.csv     Australia           New Zealand
# 6        file6.csv     Australia           New Zealand
# 7        file7.csv     Australia           New Zealand
# 8        file9.csv      Scotland           Afghanistan
# 9       file11.csv      Scotland             Hong Kong
# 10      file12.csv      Zimbabwe                 India
# 11      file13.csv      Zimbabwe                 India
# 12      file14.csv      Zimbabwe                 India
# 13      file15.csv   New Zealand            Bangladesh
# 14      file16.csv   New Zealand            Bangladesh
# 15      file17.csv   New Zealand            Bangladesh
# ...

# %%
df_meta_details['file_name']
# Out:
# 0          file0.csv
# 1          file1.csv
# 2          file2.csv
# 3          file3.csv
# 4          file4.csv
# 5          file5.csv
# 6          file6.csv
# 7          file7.csv
# 8          file9.csv
# 9         file11.csv
# 10        file12.csv
# 11        file13.csv
# 12        file14.csv
# 13        file15.csv
# 14        file16.csv
# 15        file17.csv
# 16        file18.csv
# 17        file19.csv
# 18        file20.csv
# 19        file21.csv
# 20        file22.csv
# 21        file23.csv
# 22        file24.csv
# 23        file25.csv
# 24        file27.csv
# 25        file28.csv
# 26        file30.csv
# 27        file31.csv
# 28        file32.csv
# 29        file33.csv
#             ...
# 1278    file1349.csv
# 1279    file1350.csv
# 1280    file1351.csv
# 1281    file1352.csv
# 1282    file1353.csv
# 1283    file1354.csv
# 1284    file1355.csv
# 1285    file1356.csv
# 1286    file1357.csv
# 1287    file1358.csv
# 1288    file1359.csv
# 1289    file1360.csv
# ...
